# %% [markdown]
# # Hackerrank question

# %%
"""
Q.1. Task

You have a test string . Your task is to match the string 
hackerrank. This is case sensitive.
"""

Regex_Pattern = r'\bhackerrank\b'	# Do not delete 'r'.
Regex_Pattern = r'(?s).*?hackerrank'    # Do not delete 'r'.

# the following does not work because * is greedy and will 
# consume everyting until it only matches the latter hackerrank

# %% [markdown]
# Q.2.
#
# ![image.png](attachment:image.png)

# %%
regex_pattern = r"^.{3}\..{3}\..{3}\..{3}$"	# Do not delete 'r'.

import re
import sys

test_string = input()

match = re.match(regex_pattern, test_string) is not None

print(str(match).lower())

# %%
"""
Q.3. Task

You have a test string . Your task is to write a regular 
expression that matches only and exactly strings of form: , 
where each variable  can be any single character except the 
newline.


"""
